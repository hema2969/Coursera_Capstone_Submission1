# %% [markdown]
# # **WELCOME TO THE FIRST CAPSTONE PROJECT! ** :)

# %% [markdown]
# ## The below code snippet is an example of using Numpy library to display image as an Multi-Dimensional Array.

# %%
from PIL import Image              
from IPython.display import display  # using Ipython display function to plot an image on Jupyter Notebook
import numpy as np

pil_im = Image.open("download.jpg")
display(pil_im)
print (np.array(pil_im))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7F3FDF1F7518>
# [[[138 179  85]
#   [136 177  83]
#   [134 175  79]
#   ...
#   [ 15  31   2]
#   [ 15  31   2]
#   [ 15  31   2]]
#
#  [[121 162  68]
#   [125 166  70]
#   [133 175  77]
#   ...
#   [ 14  30   1]
#   [ 15  31   2]
#   [ 15  31   2]]
#
#  [[109 150  56]
#   [110 151  55]
#   [121 163  65]
#   ...
#   [ 14  30   1]
#   [ 14  30   1]
#   [ 15  31   2]]
#
#  ...
#
#  [[ 97 108  50]
#   [ 83  97  38]
#   [ 66  84  22]
#   ...
#   [164 164 174]
#   [164 164 174]
#   [164 164 174]]
#
#  [[146 118  96]
#   [134 109  79]
#   [115  92  58]
#   ...
#   [171 173 185]
#   [171 173 185]
#   [171 173 185]]
#
#  [[192 164 142]
#   [176 151 121]
#   [151 128  94]
#   ...
#   [171 173 185]
#   [171 173 185]
#   [171 173 185]]]

# %%
from PIL import Image              
from IPython.display import display 
import numpy as np

pil_im = Image.open("download.jpg")
display(pil_im)

#print (np.array(pil_im))

# using matplotlib library 

import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

pil_im = Image.open('download.jpg')

im_array = np.asarray(pil_im)
plt.imshow(im_array)
plt.show()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x7F3FDEFB02B0>

# %% [markdown]
# ## The below code snippet is an example of using the Pandas library in Python3 to display the first few contents of data in Tabular Format.

# %%
import pandas as pd
file_read = pd.read_csv('medals.csv') # file-read --> hyphen cant be used. 
file_read.head() # pandas dataframe default displays first five rows unless row specification is been passed as an argument.
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %% [markdown]
# ## These are the different Markdown styles for displaying texts in different HTML Header Fonts.

# %% [markdown]
# #### Heading 4
# ##### Heading 5

# %% [markdown]
# ###### Heading 6
# ####### Heading 7

# %% [markdown]
# ##### Note that the heading-7 does not display any HTML header font as its counter part does not exist in HTML. Hence is not rendered in any form but just as plain text.

# %% [markdown]
# # Heading1

# %% [markdown]
# ## Heading2

# %%
print ("Thankyou, for visiting my First Capstone Project created as part of IBM DataScience Professional Certification !!")
# Out:
# Thankyou, for visiting my First Capstone Project created as part of IBM DataScience Professional Certification !!

# %% [markdown]
# # *Thankyou! ;)*
